# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/RKI_COVID19.csv')
df.head()
# Out:
#    IdBundesland      Bundesland     Landkreis Altersgruppe Geschlecht  \
# 0            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          M
# 1            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          W
# 2            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          W
# 3            15  Sachsen-Anhalt  SK Magdeburg      A60-A79          M
# 4            15  Sachsen-Anhalt  SK Magdeburg      A60-A79          M
#
#    AnzahlFall  AnzahlTodesfall  ObjectId                Meldedatum IdLandkreis
# 0           2                0    154936  2020-03-18T00:00:00.000Z       15003
# 1           1                0    154937  2020-03-12T00:00:00.000Z       15003
# 2           1                0    154938  2020-03-17T00:00:00.000Z       15003
# 3           1                0    154939  2020-03-10T00:00:00.000Z       15003
# 4           1                0    154940  2020-03-19T00:00:00.000Z       15003

# %%
df = df[df['IdLandkreis']!='0-1']

# %%
nuts = pd.read_csv('data/RKI_Corona_Landkreise.csv')
nuts = nuts.filter(['county', 'NUTS'])

# %%
merged_left = pd.merge(left=df, right=nuts, how='left', left_on='Landkreis', right_on='county').drop(columns=['county'])
merged_left.head()
# Out:
#    IdBundesland      Bundesland     Landkreis Altersgruppe Geschlecht  \
# 0            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          M
# 1            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          W
# 2            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          W
# 3            15  Sachsen-Anhalt  SK Magdeburg      A60-A79          M
# 4            15  Sachsen-Anhalt  SK Magdeburg      A60-A79          M
#
#    AnzahlFall  AnzahlTodesfall  ObjectId                Meldedatum  \
# 0           2                0    154936  2020-03-18T00:00:00.000Z
# 1           1                0    154937  2020-03-12T00:00:00.000Z
# 2           1                0    154938  2020-03-17T00:00:00.000Z
# 3           1                0    154939  2020-03-10T00:00:00.000Z
# 4           1                0    154940  2020-03-19T00:00:00.000Z
#
#   IdLandkreis   NUTS
# 0       15003  DEE03
# 1       15003  DEE03
# 2       15003  DEE03
# 3       15003  DEE03
# 4       15003  DEE03

# %%
BV = pd.read_csv('data/Landkreise1.csv', encoding = "utf-8", sep=';').drop(columns=['LandkreisId'])
#BV['LandkreisId'] = BV['LandkreisId'].apply(lambda x: '{0:0>5}'.format(x))
#BV['Bevoelkerung', ' maennlich', 'weiblich', 'Dichte'] = BV['Bevoelkerung', ' maennlich', 'weiblich', 'Dichte'].str.strip()
#BV['Bevoelkerung'] = BV['Bevoelkerung'].str.strip()
BV.head()
# Out:
#    NUTS3      Flaeche Bevoelkerung   maennlich    weiblich    Dichte
# 0  DEF01        56,73       89 504      44 599      44 905     1 578
# 1  DEF02       118,65      247 548     120 566     126 982     2 086
# 2  DEF03       214,19      217 198     104 371     112 827     1 014
# 3  DEF04        71,66       79 487      39 241      40 246     1 109
# 4  DEF05     1 428,17      133 210      65 720      67 490        93

# %%
BV['NUTS3'].unique()
# Out:
# array(['DEF01', 'DEF02', 'DEF03', 'DEF04', 'DEF05', 'DEF06', 'DEF07',
#        'DEF08', 'DEF09', 'DEF0A', 'DEF0B', 'DEF0C', 'DEF0D', 'DEF0E',
#        'DEF0F', 'DE600', 'DE911', 'DE912', 'DE913', 'DE914', 'DE916',
#        'DE917', 'DE918', 'DE91A', 'DE91B', 'DE91C', 'DE929', 'DE922',
#        'DE923', 'DE925', 'DE926', 'DE927', 'DE928', 'DE931', 'DE932',
#        'DE933', 'DE934', 'DE935', 'DE936', 'DE937', 'DE938', 'DE939',
#        'DE93A', 'DE93B', 'DE941', 'DE942', 'DE943', 'DE944', 'DE945',
#        'DE946', 'DE947', 'DE948', 'DE949', 'DE94A', 'DE94B', 'DE94C',
#        'DE94D', 'DE94E', 'DE94F', 'DE94G', 'DE94H', 'DE501', 'DE502',
#        'DEA11', 'DEA12', 'DEA13', 'DEA14', 'DEA15', 'DEA16', 'DEA17',
#        'DEA18', 'DEA19', 'DEA1A', 'DEA1B', 'DEA1C', 'DEA1D', 'DEA1E',
#        'DEA1F', 'DEA22', 'DEA23', 'DEA24', 'DEA2D', 'DEA26', 'DEA27',
#        'DEA28', 'DEA29', 'DEA2A', 'DEA2B', 'DEA2C', 'DEA31', 'DEA32',
# ...

# %%
merged_left['NUTS'].unique()
# Out:
# array(['DEE03', 'DEE04', 'DEE05', 'DEE07', 'DEE08', 'DEE09', 'DEE06',
#        'DEE0A', 'DEE0B', 'DEE0C', 'DEE0D', 'DEE0E', 'DEG01', 'DEG02',
#        'DEG03', 'DEG04', 'DEG05', 'DEG0N', 'DEG06', 'DEG07', 'DEG0P',
#        'DEG09', 'DEG0A', 'DEG0B', 'DEG0C', 'DEG0D', 'DEG0E', 'DEG0F',
#        'DEG0G', 'DEG0I', 'DEG0J', 'DEG0K', 'DEG0L', 'DEG0M', 'DE501',
#        'DE502', 'DEA11', 'DEA12', 'DEA13', 'DEA14', 'DEA15', 'DEA16',
#        'DEA17', 'DEA18', 'DEA19', 'DEA1A', 'DEA1B', 'DEA1C', 'DEA1D',
#        'DEA1E', 'DEA1F', 'DEA22', 'DEA23', 'DEA24', 'DEA2D', 'DEA26',
#        'DEA27', 'DEA28', 'DEA29', 'DEA2A', 'DEA2B', 'DEA2C', 'DEA31',
#        'DEA32', 'DEA33', 'DEA34', 'DEA35', 'DEA36', 'DEA37', 'DEF01',
#        'DEF02', 'DEF03', 'DEF04', 'DEF05', 'DEF06', 'DEF07', 'DEF08',
#        'DEF09', 'DEF0A', 'DEF0B', 'DEF0C', 'DEF0D', 'DEF0E', 'DEF0F',
#        'DE600', 'DE911', 'DE912', 'DE913', 'DE914', 'DE916', 'DE917',
# ...

# %%
merged_BV = pd.merge(left=merged_left, right=BV, how='left', left_on='NUTS', right_on='NUTS3')
merged_BV.head()
# Out:
#    IdBundesland      Bundesland     Landkreis Altersgruppe Geschlecht  \
# 0            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          M
# 1            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          W
# 2            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          W
# 3            15  Sachsen-Anhalt  SK Magdeburg      A60-A79          M
# 4            15  Sachsen-Anhalt  SK Magdeburg      A60-A79          M
#
#    AnzahlFall  AnzahlTodesfall  ObjectId                Meldedatum  \
# 0           2                0    154936  2020-03-18T00:00:00.000Z
# 1           1                0    154937  2020-03-12T00:00:00.000Z
# 2           1                0    154938  2020-03-17T00:00:00.000Z
# 3           1                0    154939  2020-03-10T00:00:00.000Z
# 4           1                0    154940  2020-03-19T00:00:00.000Z
#
#   IdLandkreis   NUTS NUTS3 Flaeche Bevoelkerung maennlich weiblich Dichte
# ...

# %%
Alter = pd.read_csv('data/Altersgruppen_Geschlecht.csv', encoding = "utf-8", sep=';')
Alter.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf6 in position 3: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-97-43483579168f> in <module>()
# ----> 1 Alter = pd.read_csv('data/Altersgruppen_Geschlecht.csv', encoding = "utf-8", sep=';')
#       2 Alter.head()
#
# ...

# %%
# Out:
#    IdBundesland      Bundesland     Landkreis Altersgruppe Geschlecht  \
# 0            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          M
# 1            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          W
# 2            15  Sachsen-Anhalt  SK Magdeburg      A35-A59          W
# 3            15  Sachsen-Anhalt  SK Magdeburg      A60-A79          M
# 4            15  Sachsen-Anhalt  SK Magdeburg      A60-A79          M
#
#    AnzahlFall  AnzahlTodesfall  ObjectId                Meldedatum  \
# 0           2                0    154936  2020-03-18T00:00:00.000Z
# 1           1                0    154937  2020-03-12T00:00:00.000Z
# 2           1                0    154938  2020-03-17T00:00:00.000Z
# 3           1                0    154939  2020-03-10T00:00:00.000Z
# 4           1                0    154940  2020-03-19T00:00:00.000Z
#
#   IdLandkreis        county   NUTS
# 0       15003  SK Magdeburg  DEE03
# 1       15003  SK Magdeburg  DEE03
# ...
