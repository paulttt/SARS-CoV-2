# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/RKI_Corona_Landkreise.csv')
df.head()
# Out:
#    OBJECTID  ADE   GF  BSG    RS     AGS        SDV_RS           GEN  \
# 0         1  4.0  4.0  1.0  1001  1001.0  1.001000e+10     Flensburg
# 1         2  4.0  4.0  1.0  1002  1002.0  1.002000e+10          Kiel
# 2         3  4.0  4.0  1.0  1003  1003.0  1.003000e+10        Lübeck
# 3         4  4.0  4.0  1.0  1004  1004.0  1.004000e+10    Neumünster
# 4         5  4.0  4.0  1.0  1051  1051.0  1.051004e+10  Dithmarschen
#
#                 BEZ   IBZ  ...   Shape__Area  Shape__Length  death_rate  \
# 0  Kreisfreie Stadt  40.0  ...  4.918293e+07   42752.592015    0.000000
# 1  Kreisfreie Stadt  40.0  ...  1.122314e+08  104373.457289    0.000000
# 2  Kreisfreie Stadt  40.0  ...  2.116771e+08  146459.457897    4.761905
# 3  Kreisfreie Stadt  40.0  ...  7.140224e+07   54863.995416    0.000000
# 4             Kreis  42.0  ...  1.425511e+09  250768.570200    0.000000
#
#    cases  deaths  cases_per_100k  cases_per_population                  BL  \
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID', 'ADE', 'GF', 'BSG', 'RS', 'AGS', 'SDV_RS', 'GEN', 'BEZ',
#        'IBZ', 'BEM', 'NBD', 'SN_L', 'SN_R', 'SN_K', 'SN_V1', 'SN_V2', 'SN_G',
#        'FK_S3', 'NUTS', 'RS_0', 'AGS_0', 'WSK', 'EWZ', 'KFL', 'DEBKG_ID',
#        'Shape__Area', 'Shape__Length', 'death_rate', 'cases', 'deaths',
#        'cases_per_100k', 'cases_per_population', 'BL', 'BL_ID', 'county'],
#       dtype='object')
